# %%
import pandas as pd
df = pd.read_csv("./yf/prediction_201808_sorted.csv")
df
# Out:
#             price  postcode               paon                     saon  \
# 0        335000.0   SM5 1HS                365                      NaN
# 1        148750.0   CV2 3BU                 38                      NaN
# 2        445000.0  ME14 2EQ                 15                      NaN
# 3        325000.0  TN10 3HS                  1                      NaN
# 4         91000.0   CW8 1BP  WEAVER VIEW FLATS                        4
# 5        125000.0  SA18 2FL                122                      NaN
# 6        189950.0   NE5 5AJ                 51                      NaN
# 7        240000.0  PO22 9QG                  4                      NaN
# 8        178000.0  NN15 6JD                117                      NaN
# 9        144000.0   WF1 3BY                  6                      NaN
# 10       174000.0  DN21 2TD                 19                      NaN
# 11       177500.0  BD23 4PT         HIGH CROFT                      NaN
# ...
